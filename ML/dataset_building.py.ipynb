# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### Load dataset

# %%
symp_dict = pickle.load(open("Disease-symptoms.pkl",'rb'))

# %%
symp_dict
# Out:
# {'Alcohol Abuse and Alcoholism': 'Drinking large amounts of alcohol over a long period, difficulty cutting down, acquiring and drinking alcohol taking up a lot of time, usage resulting in problems, withdrawal occurring when stopping,',
#  'Alopecia (hair loss)': 'Loss of hair from part of the head or body,',
#  'Anxiety': 'Social isolation, hypervigilance, feeling of inferiority, low self-esteem, difficulty socializing with others,',
#  'Appendicitis': 'Right lower abdominal pain, vomiting, decreased appetite,',
#  'Autism': 'Trouble with social interaction, verbal and nonverbal communication, and presence of restricted interests and repetitive behavior,',
#  'Acquired Immuno Deficiency Syndrome': 'Flu-like illness,',
#  "Alzheimer's Disease": 'Difficulty in remembering recent events, problems with language, disorientation, mood swings,',
#  'Anaemia': 'Feeling tired, pale skin, weakness, shortness of breath, feeling like passing out,',
#  'Arthritis': 'Joint pain, stiffness, redness, swelling, decreased range of motion,',
#  'Asthma': 'Recurring episodes of wheezing, coughing, chest tightness, shortness of breath,',
#  'Anthrax': 'small blister with surrounding swelling, fever, chest pain, shortness of breath, nausea, vomiting, diarrhea, abdominal pain, fever, abscess,',
#  'Amoebiasis': 'Bloody diarrhea, abdominal pain,',
#  'Atherosclerosis': 'None,',
#  'Adult Inclusion Conjunctivitis': 'Reddish eye, scratchiness,',
#  'Astigmatism': 'Distorted or blurred vision at all distances, eyestrain, headaches,',
#  'Anisometropia': 'One eye is myopia other eye is hyperopia,',
#  'Aniseikonia': 'objects different sizes in each eye,',
#  'Asbestos-related diseases': 'Shortness of breath, cough, wheezing, chest pain,',
#  'Amblyopia': 'Decreased vision,',
#  'Abnormal uterine bleeding': 'Irregular, abnormally frequent, prolonged, or excessive amounts of uterine bleeding,',
#  'Acquired Capillary Haemangioma of Eyelid': 'Raised red or blue lesion,',
#  'Acute encephalitis syndrome': 'Headache, fever, confusion, stiff neck, vomiting,',
#  'Amaurosis Fugax': 'Temporary fleeting of vision in one or both eyes,',
#  'Blindness': 'Decreased ability to see,',
#  'Breast Cancer / Carcinoma': 'A lump in a breast, a change in breast shape, dimpling of the skin, fluid from the nipple, a newly inverted nipple, a red scaly patch of skin on the breast,',
#  'Bronchitis': 'Coughing up mucus, wheezing, shortness of breath, chest discomfort,',
#  'Brucellosis': 'coughing,',
#  "Bell's Palsy": 'Inability to move the facial muscles on one side, change in taste, pain around the ear,',
#  'Brain Tumour': 'Vary depending on the part of the brain involved, headaches, seizures, problem with vision, vomiting, mental changes,',
#  'Blepharitis': 'crusty eyelids,',
#  'Burns': 'Red without blisters,',
#  'Bad Breath (Halitosis)': 'Unpleasant smell present on breath,',
#  'Cancer': 'Lump, abnormal bleeding, prolonged cough, unexplained weight loss, change in bowel movements,',
#  'Carpal Tunnel Syndrome': 'Pain, numbness, tingling in the thumb, index, middle finger, and half of ring finger, weak grip,',
#  'Chickenpox': 'Small, itchy blisters, headache, loss of appetite, tiredness, fever,',
#  'Chikungunya Fever': 'Fever, joint pain,',
#  'Cholera': 'Large amounts of watery diarrhea, vomiting, muscle cramps,',
#  'Coronary Heart Disease': 'Chest pain, shortness of breath,',
#  'Cough': 'Runny nose, fever, cough,',
#  'Childhood Exotropia': 'Nonaligned eyes,',
#  'Chalazion': 'Red, non painful cyst in middle of the eyelid,',
#  'Crimean-Congo haemorrhagic fever (CCHF)': 'Fever, muscle pains, headache, vomiting, diarrhea, bleeding into the skin,',
#  'Chronic obstructive pulmonary disease (COPD)': 'Shortness of breath, chronic cough,',
#  'Coronavirus disease 2019 (COVID-19)': 'Fever, cough, fatigue, shortness of breath, vomiting, loss of taste or smell, some cases asymptomatic,',
#  'Congenital anomalies (birth defects)': 'Physical disability, intellectual disability, developmental disability,',
#  'Cervical cancer': 'none,',
#  'Colorectal Cancer': 'vomiting blood, Blood in the stool, change in bowel movements, weight loss, fatigue,',
#  'Corneal Abrasion': 'Eye pain, light sensitivity,',
#  'Cavities': 'Pain, tooth loss, difficulty eating,',
#  'Cleft Lip and Cleft Palate': 'Opening in the upper lip that may extend into the nose or palate,',
#  'Diarrhea': 'Loose frequent bowel movements, dehydration,',
#  'Deafness': 'Decreased ability to hear,',
#  'Dementia': 'Decreased ability to think and remember, emotional problems, problems with language, decreased motivation,',
#  'Dengue Fever': 'Fever, headache, muscle and joint pain, rash,',
#  'Diabetes Mellitus': 'Frequent urination, increased thirst, increased hunger,',
#  "Down's Syndrome": 'Delayed physical growth, characteristic facial features, mild to moderate intellectual disability,',
#  'Diabetic Retinopathy': 'May have no symptoms, blurry vision, vision loss, blindness,',
#  'Diphtheria': 'Sore throat, fever, barking cough,',
#  'Dracunculiasis (guinea-worm disease)': 'Painful blister that a white worm crawls out of,',
#  'Ebola Virus Disease (EVD)': 'Fever, sore throat, muscular pain, headaches, diarrhoea, bleeding,',
#  'Eczema': 'Itchiness, red skin, rash,',
#  'Endometriosis': 'Pelvic pain, infertility,',
#  'Epilepsy': 'Periods of vigorous shaking, nearly undetectable spells,',
#  'Ectopic pregnancy': 'Abdominal pain, vaginal bleeding,',
#  'Exposure Keratopathy': 'Dryness, irritation, redness, eye pain and photophobia,',
#  'Early pregnancy loss': 'Vaginal bleeding with or without pain,',
#  'Eclampsia': 'Seizures, high blood pressure,',
#  'Fibroids': 'Painful or heavy periods,',
#  'Filariasis': 'None, severe swelling of the arms, legs, breasts, or genitals,',
#  "Frey's Syndrome": 'Redness and sweating of cheek area when salivating,',
#  'Frost Bite': 'Numbness, feeling cold, clumsiness, pale color,',
#  'Filamentary Keratitis': 'Eye pain, blurred vision, red eye, eye discharge, photophobia, corneal ulceration,',
#  'Factitious Keratoconjunctivitis': 'Firmly attached white patch on a mucous membrane, changes with time,',
#  'Fibromyalgia': 'Widespread pain, feeling tired, sleep problems,',
#  'Gangrene': 'Change in skin color to red or black, numbness, pain, skin breakdown, coolness,',
#  'Gastro-Esophageal Reflux Disease (GERD)': 'Taste of acid, heartburn, bad breath, chest pain, breathing problems,',
#  'Glaucoma': 'Vision loss, eye pain, mid-dilated pupil, redness of the eye, nausea,',
#  'Goitre': 'Enlarged thyroid, irritability, muscle weakness, sleeping problems, fast heartbeat, weight loss, poor tolerance of heat,',
#  'Gonorrhea': 'None, burning with urination, vaginal discharge, discharge from the penis, pelvic pain, testicular pain,',
#  'Guillain-Barré syndrome': 'Muscle weakness beginning in the feet and hands, usually ascending,',
#  'Gaming disorder': 'Problem gambling,, depression, social withdrawal, playing video games for extremely long periods of time,',
#  'Gum disease': 'Red, swollen, painful, bleeding gums, loose teeth, bad breath,',
#  'Hepatitis': 'Yellowish skin, poor appetite, abdominal pain,',
#  'Herpes Simplex': 'Blisters that break open and form small ulcers, fever, swollen lymph nodes,',
#  'Haemophilia': 'Easy and prolonged bleeding,',
#  'Heat-Related Illnesses and Heat waves': 'High body temperature, red, dry or damp skin, headache, dizziness, confusion, nausea,',
#  'Hand, Foot and Mouth Disease': 'Fever, flat discolored spots or bumps that may blister,',
#  'Hypermetropia': 'Near blur, Distance and near blur, Asthenopia,',
#  'High risk pregnancy': 'Missed periods, tender breasts, nausea and vomiting, hunger, frequent urination,',
#  'Inflammatory Bowel Disease': 'Abdominal pain, diarrhoea (may be bloody), fever, weight loss,',
#  'Insomnia': 'Trouble sleeping, daytime sleepiness, low energy, irritability, depressed mood,',
#  'Iron Deficiency Anemia': 'Feeling tired, weakness, shortness of breath, confusion, pallor,',
#  'Japanese Encephalitis': 'Headache, fever, vomiting, confusion, seizures,',
#  'Jaundice': 'Yellowish coloration of skin and whites of the eyes, itchiness,',
#  'Kala-azar/ Leishmaniasis': 'Skin ulcers, fever, low red blood cells, enlarged liver,',
#  'Kaposi’s Sarcoma': 'Purple colored skin lesions,',
#  'Keratoconjunctivitis Sicca (Dry eye syndrome)': 'Dry eyes, irritation, redness, discharge, blurred vision,',
#  'Keratoconus': 'Blurry vision, nearsightedness, light sensitivity,',
#  'Leprosy': 'Decreased ability to feel pain,',
#  'Leptospirosis': 'None, headaches, muscle pains, fevers,',
#  'Leukemia': 'Bleeding, bruising, fatigue, fever, increased risk of infections,',
#  'Lymphoedema': 'Swelling, pain, tenderness, erythema, limited range of motion in both ankles,',
#  'Lead poisoning': 'Intellectual disability, abdominal pain, constipation, headaches, irritability, memory problems, inability to have children, tingling in the hands and feet,',
#  'lactose intolerance': 'Abdominal pain, bloating, diarrhea, flatulence, nausea,',
#  'Measles(Khasra)': 'Fever, cough, runny nose, inflamed eyes, rash,',
#  'Malaria': 'Fever, vomiting, headache, yellow skin,',
#  'Meningitis': 'Fever, headache, neck stiffness,',
#  'Migraine': 'Headaches, nausea, sensitivity to light, sensitivity to sound, sensitivity to smell,',
#  'Myocardial Infarction (Heart Attack)': 'Chest pain, shortness of breath, nausea, feeling faint, cold sweat, feeling tired, arm, neck, back, jaw, or stomach pain,',
#  'Microcephaly': 'Abnormally small head and brain, neurological impairments,',
#  'Middle East respiratory syndrome coronavirus (MERS‐CoV)': 'Fever, cough, shortness of breath,',
#  'Myopia': 'Distant objects appear blurry, close objects appear normal, headaches, eye strain,',
#  'Mumps': 'Parotitis and non-specific symptoms such as fever, headache, malaise, muscle pain, and loss of appetite,',
#  'Mastitis': 'Localized breast pain and redness, fever,',
#  'Mucormycosis': 'Depends on location: runny nose, black area of skin, facial swelling, headache, fever, cough, blurred vision,',
#  'Mouth Breathing': 'Snoring, dry mouth, hoarse voice, bad breath, fatigue,',
#  'Narcolepsy': 'Excessive daytime sleepiness, involuntary sleep episodes, sudden loss of muscle strength, hallucinations,',
#  'Nasal Polyps': 'Trouble breathing through the nose, loss of smell, decreased taste, post nasal drip, runny nose,',
#  'Nipah virus infection': 'None, fever, cough, headache,diarrhea, confusion,',
#  'Nausea and Vomiting of Pregnancy and  Hyperemesis gravidarum': 'Nausea and vomiting such that weight loss and dehydration occur,',
#  'Nonalcoholic fatty liver disease(NAFLD)': 'Asymptomatic, liver dysfunction,',
#  'Obsessive Compulsive Disorder': 'Feel the need to check things repeatedly, perform certain routines repeatedly, have certain thoughts repeatedly,',
#  'Oral Cancer': 'Persistent rough white or red patch in the mouth lasting longer than 2 weeks, ulceration, lumps/bumps in the neck, pain, loose teeth, difficulty swallowing,',
#  'Osteomyelitis': 'Pain in a specific bone, overlying redness, fever, weakness,',
#  'Osteoporosis': 'Increased risk of a broken bone,',
#  'Otitis Media': 'Ear pain, fever, hearing loss,',
#  'Orbital Dermoid': 'Minimal, painless lump,',
#  'Obesity': 'Increased fat,',
#  'Osteoarthritis': 'Joint pain, stiffness, joint swelling, decreased range of motion,',
#  'Psoriasis': 'Red (purple on darker skin), itchy, scaly patches of skin,',
#  "Parkinson's Disease": 'Tremor, rigidity, slowness of movement, difficulty walking,',
#  'Pericarditis': 'Sharp chest pain, better sitting up and worse with lying down, fever,',
#  'Pneumonia': 'Cough, difficulty breathing, rapid breathing, fever,',
#  'Poliomyelitis': 'Muscle weakness resulting in an inability to move,',
#  'Pterygium': 'Pinkish, triangular tissue growth on the cornea,',
#  'Polycystic ovary syndrome (PCOS)': 'Irregular menstrual periods, heavy periods, excess hair, acne, pelvic pain, difficulty getting pregnant, patches of thick, darker, velvety skin,',
#  'Plague': 'Fever, weakness, headache,',
#  'Preterm birth': "Birth of a baby at younger than 37 weeks' gestational age,",
#  'Preeclampsia': 'High blood pressure, protein in the urine,',
#  'Pellucid Marginal Degeneration': 'Vision loss,',
#  'Presbyopia': 'Difficulty reading small print, having to hold reading material farther away, headaches, eyestrain,',
#  'Premenstrual syndrome': 'Acne, tender breasts, cramps, bloating, feeling tired, sore throat, mood changes,',
#  'Puerperal sepsis': 'Fever, lower abdominal pain, bad-smelling vaginal discharge,',
#  'Postpartum haemorrhage': 'Significant blood loss after childbirth, increased heart rate, feeling faint upon standing, increased breath rate,',
#  'Post-herpetic neuralgia': "burning or stabbing pain, pain doesn't end after the shingles subsides,",
#  'Postpartum depression/ Perinatal depression': 'Extreme sadness, low energy, anxiety, changes in sleeping or eating patterns, crying episodes, irritability,',
#  'Quinsy': 'Fever, throat pain, trouble opening the mouth, change to the voice,',
#  'Rabies': 'Fever, fear of water, confusion, excessive salivation, hallucinations, trouble sleeping, paralysis, coma,',
#  "Raynaud's Phenomenon": 'An affected part turning white, then blue, then red, burning,',
#  'Rubella': 'Rash, swollen lymph nodes, fever, sore throat, feeling tired,',
#  'Rheumatic fever and rheumatic heart disease': 'Fever, multiple painful joints, involuntary muscle movements, erythema marginatum,',
#  'Sarcoidosis': 'Depends on the organ involved,',
#  'Sarcoma': 'Swell and pain near the tumor,',
#  'Schizophrenia': 'Hallucinations (usually hearing voices), delusions, paranoia, confused thinking,',
#  'Scurvy': 'Weakness, feeling tired, changes to hair, sore arms and legs, gum disease, easy bleeding,',
#  'Severe Acute Respiratory Syndrome (SARS)': 'Fever, persistent dry cough, headache, muscle pains, difficulty breathing,',
#  'Syphilis': 'Firm, painless, non-itchy skin ulcer,',
#  'Superior Limbic Keratoconjunctivitis': 'Eye redness, burning sensation, tearing,',
#  'Stroke': 'Inability to move or feel on one side of the body, problems understanding or speaking, dizziness, loss of vision to one side,',
#  'Scrub Typhus': 'Fever, headache, rash,',
#  'Sexually transmitted infections (STIs)': 'None, vaginal discharge, penile discharge, ulcers on or around the genitals, pelvic pain,',
#  'Shaken Baby Syndrome': 'Variable,',
#  'Substance abuse': 'Relationship difficulties, legal problems, problems at work or school, insomnia, irritability, chronic fatigue,',
#  'Scabies': 'itchiness, pimple-like rash,',
#  'Sub-conjunctival Haemorrhage': 'Red spot over whites of the eye, little to no pain,',
#  'Tetanus': 'Muscle spasms, fever, headache,',
#  'Thalassaemia': 'Feeling tired, pale skin, enlarged spleen, yellowish skin, dark urine,',
#  'Tuberculosis': 'Chronic cough, fever, cough with bloody mucus, weight loss,',
#  'Turners Syndrome': 'Webbed neck, short stature, swollen hands and feet,',
#  'Trachoma': 'Eye pain, blindness,',
#  'Taeniasis/cysticercosis': '1–2 cm lumps under the skin,',
#  'Typhoid / Enteric Fever': 'Fever that starts low and increases daily, possibly reaching as high as 1049 °F (405 °C) Headache, Weakness and fatigue, Muscle aches, Sweating, Dry cough, Loss of appetite and weight loss, Stomach pain, Diarrhea or constipation, Rash, Swollen stomach (enlarged liver or spleen),',
#  'Ulcerative Colitis': 'Abdominal pain, diarrhea mixed with blood, weight loss, fever, anemia,',
#  'Urticaria': 'Red, raised, itchy bumps,',
#  'Varicose Veins': 'None, fullness, pain in the area,',
#  'Vitamin B12 Deficiency': 'Presence of anemia, decreased ability to think, depression, irritability, abnormal sensations, changes in reflexes,',
#  'Vitiligo': 'Patches of white skin,',
#  'Xerophthalmia': 'Night blindness,',
#  'Yellow Fever': 'Fever, chills, muscle pain, headache, yellow skin,',
#  'Yaws': 'Hard swelling of the skin, ulcer, joint and bone pain,'}

# %% [markdown]
# # Data Preprocessing

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from time import time

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
lemmatizer  = WordNetLemmatizer()

# %%
from nltk.tokenize import RegexpTokenizer

# %%
splitter = RegexpTokenizer(r'\w+')

# %%
total_symp = set()

# %%
cleaned_symp_dict = {}

# %%
for key in symp_dict.keys():
    value = symp_dict[key]
    symp_list = value.lower().split(',')
    temp_list = []
    for sym in symp_list:
        if len(sym.strip())>0:
            temp_list.append(sym.strip())
    if "none" in temp_list:
        temp_list.remove("none")
    if len(temp_list)==0:
        continue
    temp =[]
    for sym in temp_list:
        sym=sym.replace('-',' ')
        sym=sym.replace("'",'')
        sym=sym.replace('(','')
        sym=sym.replace(')','')
        sym = ' '.join([lemmatizer.lemmatize(word) for word in splitter.tokenize(sym) if word not in stop_words and not word[0].isdigit()])
        total_symp.add(sym)
        temp.append(sym)
    cleaned_symp_dict[key] = temp

# %%
cleaned_symp_dict
# Out:
# {'Alcohol Abuse and Alcoholism': ['drinking large amount alcohol long period',
#   'difficulty cutting',
#   'acquiring drinking alcohol taking lot time',
#   'usage resulting problem',
#   'withdrawal occurring stopping'],
#  'Alopecia (hair loss)': ['loss hair part head body'],
#  'Anxiety': ['social isolation',
#   'hypervigilance',
#   'feeling inferiority',
#   'low self esteem',
#   'difficulty socializing others'],
#  'Appendicitis': ['right lower abdominal pain',
#   'vomiting',
#   'decreased appetite'],
#  'Autism': ['trouble social interaction',
#   'verbal nonverbal communication',
#   'presence restricted interest repetitive behavior'],
#  'Acquired Immuno Deficiency Syndrome': ['flu like illness'],
#  "Alzheimer's Disease": ['difficulty remembering recent event',
#   'problem language',
#   'disorientation',
#   'mood swing'],
#  'Anaemia': ['feeling tired',
#   'pale skin',
#   'weakness',
#   'shortness breath',
#   'feeling like passing'],
#  'Arthritis': ['joint pain',
#   'stiffness',
#   'redness',
#   'swelling',
#   'decreased range motion'],
#  'Asthma': ['recurring episode wheezing',
#   'coughing',
#   'chest tightness',
#   'shortness breath'],
#  'Anthrax': ['small blister surrounding swelling',
#   'fever',
#   'chest pain',
#   'shortness breath',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'abdominal pain',
#   'fever',
#   'abscess'],
#  'Amoebiasis': ['bloody diarrhea', 'abdominal pain'],
#  'Adult Inclusion Conjunctivitis': ['reddish eye', 'scratchiness'],
#  'Astigmatism': ['distorted blurred vision distance', 'eyestrain', 'headache'],
#  'Anisometropia': ['one eye myopia eye hyperopia'],
#  'Aniseikonia': ['object different size eye'],
#  'Asbestos-related diseases': ['shortness breath',
#   'cough',
#   'wheezing',
#   'chest pain'],
#  'Amblyopia': ['decreased vision'],
#  'Abnormal uterine bleeding': ['irregular',
#   'abnormally frequent',
#   'prolonged',
#   'excessive amount uterine bleeding'],
#  'Acquired Capillary Haemangioma of Eyelid': ['raised red blue lesion'],
#  'Acute encephalitis syndrome': ['headache',
#   'fever',
#   'confusion',
#   'stiff neck',
#   'vomiting'],
#  'Amaurosis Fugax': ['temporary fleeting vision one eye'],
#  'Blindness': ['decreased ability see'],
#  'Breast Cancer / Carcinoma': ['lump breast',
#   'change breast shape',
#   'dimpling skin',
#   'fluid nipple',
#   'newly inverted nipple',
#   'red scaly patch skin breast'],
#  'Bronchitis': ['coughing mucus',
#   'wheezing',
#   'shortness breath',
#   'chest discomfort'],
#  'Brucellosis': ['coughing'],
#  "Bell's Palsy": ['inability move facial muscle one side',
#   'change taste',
#   'pain around ear'],
#  'Brain Tumour': ['vary depending part brain involved',
#   'headache',
#   'seizure',
#   'problem vision',
#   'vomiting',
#   'mental change'],
#  'Blepharitis': ['crusty eyelid'],
#  'Burns': ['red without blister'],
#  'Bad Breath (Halitosis)': ['unpleasant smell present breath'],
#  'Cancer': ['lump',
#   'abnormal bleeding',
#   'prolonged cough',
#   'unexplained weight loss',
#   'change bowel movement'],
#  'Carpal Tunnel Syndrome': ['pain',
#   'numbness',
#   'tingling thumb',
#   'index',
#   'middle finger',
#   'half ring finger',
#   'weak grip'],
#  'Chickenpox': ['small',
#   'itchy blister',
#   'headache',
#   'loss appetite',
#   'tiredness',
#   'fever'],
#  'Chikungunya Fever': ['fever', 'joint pain'],
#  'Cholera': ['large amount watery diarrhea', 'vomiting', 'muscle cramp'],
#  'Coronary Heart Disease': ['chest pain', 'shortness breath'],
#  'Cough': ['runny nose', 'fever', 'cough'],
#  'Childhood Exotropia': ['nonaligned eye'],
#  'Chalazion': ['red', 'non painful cyst middle eyelid'],
#  'Crimean-Congo haemorrhagic fever (CCHF)': ['fever',
#   'muscle pain',
#   'headache',
#   'vomiting',
#   'diarrhea',
#   'bleeding skin'],
#  'Chronic obstructive pulmonary disease (COPD)': ['shortness breath',
#   'chronic cough'],
#  'Coronavirus disease 2019 (COVID-19)': ['fever',
#   'cough',
#   'fatigue',
#   'shortness breath',
#   'vomiting',
#   'loss taste smell',
#   'case asymptomatic'],
#  'Congenital anomalies (birth defects)': ['physical disability',
#   'intellectual disability',
#   'developmental disability'],
#  'Colorectal Cancer': ['vomiting blood',
#   'blood stool',
#   'change bowel movement',
#   'weight loss',
#   'fatigue'],
#  'Corneal Abrasion': ['eye pain', 'light sensitivity'],
#  'Cavities': ['pain', 'tooth loss', 'difficulty eating'],
#  'Cleft Lip and Cleft Palate': ['opening upper lip may extend nose palate'],
#  'Diarrhea': ['loose frequent bowel movement', 'dehydration'],
#  'Deafness': ['decreased ability hear'],
#  'Dementia': ['decreased ability think remember',
#   'emotional problem',
#   'problem language',
#   'decreased motivation'],
#  'Dengue Fever': ['fever', 'headache', 'muscle joint pain', 'rash'],
#  'Diabetes Mellitus': ['frequent urination',
#   'increased thirst',
#   'increased hunger'],
#  "Down's Syndrome": ['delayed physical growth',
#   'characteristic facial feature',
#   'mild moderate intellectual disability'],
#  'Diabetic Retinopathy': ['may symptom',
#   'blurry vision',
#   'vision loss',
#   'blindness'],
#  'Diphtheria': ['sore throat', 'fever', 'barking cough'],
#  'Dracunculiasis (guinea-worm disease)': ['painful blister white worm crawl'],
#  'Ebola Virus Disease (EVD)': ['fever',
#   'sore throat',
#   'muscular pain',
#   'headache',
#   'diarrhoea',
#   'bleeding'],
#  'Eczema': ['itchiness', 'red skin', 'rash'],
#  'Endometriosis': ['pelvic pain', 'infertility'],
#  'Epilepsy': ['period vigorous shaking', 'nearly undetectable spell'],
#  'Ectopic pregnancy': ['abdominal pain', 'vaginal bleeding'],
#  'Exposure Keratopathy': ['dryness',
#   'irritation',
#   'redness',
#   'eye pain photophobia'],
#  'Early pregnancy loss': ['vaginal bleeding without pain'],
#  'Eclampsia': ['seizure', 'high blood pressure'],
#  'Fibroids': ['painful heavy period'],
#  'Filariasis': ['severe swelling arm', 'leg', 'breast', 'genitals'],
#  "Frey's Syndrome": ['redness sweating cheek area salivating'],
#  'Frost Bite': ['numbness', 'feeling cold', 'clumsiness', 'pale color'],
#  'Filamentary Keratitis': ['eye pain',
#   'blurred vision',
#   'red eye',
#   'eye discharge',
#   'photophobia',
#   'corneal ulceration'],
#  'Factitious Keratoconjunctivitis': ['firmly attached white patch mucous membrane',
#   'change time'],
#  'Fibromyalgia': ['widespread pain', 'feeling tired', 'sleep problem'],
#  'Gangrene': ['change skin color red black',
#   'numbness',
#   'pain',
#   'skin breakdown',
#   'coolness'],
#  'Gastro-Esophageal Reflux Disease (GERD)': ['taste acid',
#   'heartburn',
#   'bad breath',
#   'chest pain',
#   'breathing problem'],
#  'Glaucoma': ['vision loss',
#   'eye pain',
#   'mid dilated pupil',
#   'redness eye',
#   'nausea'],
#  'Goitre': ['enlarged thyroid',
#   'irritability',
#   'muscle weakness',
#   'sleeping problem',
#   'fast heartbeat',
#   'weight loss',
#   'poor tolerance heat'],
#  'Gonorrhea': ['burning urination',
#   'vaginal discharge',
#   'discharge penis',
#   'pelvic pain',
#   'testicular pain'],
#  'Guillain-Barré syndrome': ['muscle weakness beginning foot hand',
#   'usually ascending'],
#  'Gaming disorder': ['problem gambling',
#   'depression',
#   'social withdrawal',
#   'playing video game extremely long period time'],
#  'Gum disease': ['red',
#   'swollen',
#   'painful',
#   'bleeding gum',
#   'loose teeth',
#   'bad breath'],
#  'Hepatitis': ['yellowish skin', 'poor appetite', 'abdominal pain'],
#  'Herpes Simplex': ['blister break open form small ulcer',
#   'fever',
#   'swollen lymph node'],
#  'Haemophilia': ['easy prolonged bleeding'],
#  'Heat-Related Illnesses and Heat waves': ['high body temperature',
#   'red',
#   'dry damp skin',
#   'headache',
#   'dizziness',
#   'confusion',
#   'nausea'],
#  'Hand, Foot and Mouth Disease': ['fever',
#   'flat discolored spot bump may blister'],
#  'Hypermetropia': ['near blur', 'distance near blur', 'asthenopia'],
#  'High risk pregnancy': ['missed period',
#   'tender breast',
#   'nausea vomiting',
#   'hunger',
#   'frequent urination'],
#  'Inflammatory Bowel Disease': ['abdominal pain',
#   'diarrhoea may bloody',
#   'fever',
#   'weight loss'],
#  'Insomnia': ['trouble sleeping',
#   'daytime sleepiness',
#   'low energy',
#   'irritability',
#   'depressed mood'],
#  'Iron Deficiency Anemia': ['feeling tired',
#   'weakness',
#   'shortness breath',
#   'confusion',
#   'pallor'],
#  'Japanese Encephalitis': ['headache',
#   'fever',
#   'vomiting',
#   'confusion',
#   'seizure'],
#  'Jaundice': ['yellowish coloration skin white eye', 'itchiness'],
#  'Kala-azar/ Leishmaniasis': ['skin ulcer',
#   'fever',
#   'low red blood cell',
#   'enlarged liver'],
#  'Kaposi’s Sarcoma': ['purple colored skin lesion'],
#  'Keratoconjunctivitis Sicca (Dry eye syndrome)': ['dry eye',
#   'irritation',
#   'redness',
#   'discharge',
#   'blurred vision'],
#  'Keratoconus': ['blurry vision', 'nearsightedness', 'light sensitivity'],
#  'Leprosy': ['decreased ability feel pain'],
#  'Leptospirosis': ['headache', 'muscle pain', 'fever'],
#  'Leukemia': ['bleeding',
#   'bruising',
#   'fatigue',
#   'fever',
#   'increased risk infection'],
#  'Lymphoedema': ['swelling',
#   'pain',
#   'tenderness',
#   'erythema',
#   'limited range motion ankle'],
#  'Lead poisoning': ['intellectual disability',
#   'abdominal pain',
#   'constipation',
#   'headache',
#   'irritability',
#   'memory problem',
#   'inability child',
#   'tingling hand foot'],
#  'lactose intolerance': ['abdominal pain',
#   'bloating',
#   'diarrhea',
#   'flatulence',
#   'nausea'],
#  'Measles(Khasra)': ['fever', 'cough', 'runny nose', 'inflamed eye', 'rash'],
#  'Malaria': ['fever', 'vomiting', 'headache', 'yellow skin'],
#  'Meningitis': ['fever', 'headache', 'neck stiffness'],
#  'Migraine': ['headache',
#   'nausea',
#   'sensitivity light',
#   'sensitivity sound',
#   'sensitivity smell'],
#  'Myocardial Infarction (Heart Attack)': ['chest pain',
#   'shortness breath',
#   'nausea',
#   'feeling faint',
#   'cold sweat',
#   'feeling tired',
#   'arm',
#   'neck',
#   'back',
#   'jaw',
#   'stomach pain'],
#  'Microcephaly': ['abnormally small head brain', 'neurological impairment'],
#  'Middle East respiratory syndrome coronavirus (MERS‐CoV)': ['fever',
#   'cough',
#   'shortness breath'],
#  'Myopia': ['distant object appear blurry',
#   'close object appear normal',
#   'headache',
#   'eye strain'],
#  'Mumps': ['parotitis non specific symptom fever',
#   'headache',
#   'malaise',
#   'muscle pain',
#   'loss appetite'],
#  'Mastitis': ['localized breast pain redness', 'fever'],
#  'Mucormycosis': ['depends location runny nose',
#   'black area skin',
#   'facial swelling',
#   'headache',
#   'fever',
#   'cough',
#   'blurred vision'],
#  'Mouth Breathing': ['snoring',
#   'dry mouth',
#   'hoarse voice',
#   'bad breath',
#   'fatigue'],
#  'Narcolepsy': ['excessive daytime sleepiness',
#   'involuntary sleep episode',
#   'sudden loss muscle strength',
#   'hallucination'],
#  'Nasal Polyps': ['trouble breathing nose',
#   'loss smell',
#   'decreased taste',
#   'post nasal drip',
#   'runny nose'],
#  'Nipah virus infection': ['fever',
#   'cough',
#   'headache',
#   'diarrhea',
#   'confusion'],
#  'Nausea and Vomiting of Pregnancy and  Hyperemesis gravidarum': ['nausea vomiting weight loss dehydration occur'],
#  'Nonalcoholic fatty liver disease(NAFLD)': ['asymptomatic',
#   'liver dysfunction'],
#  'Obsessive Compulsive Disorder': ['feel need check thing repeatedly',
#   'perform certain routine repeatedly',
#   'certain thought repeatedly'],
#  'Oral Cancer': ['persistent rough white red patch mouth lasting longer week',
#   'ulceration',
#   'lump bump neck',
#   'pain',
#   'loose teeth',
#   'difficulty swallowing'],
#  'Osteomyelitis': ['pain specific bone',
#   'overlying redness',
#   'fever',
#   'weakness'],
#  'Osteoporosis': ['increased risk broken bone'],
#  'Otitis Media': ['ear pain', 'fever', 'hearing loss'],
#  'Orbital Dermoid': ['minimal', 'painless lump'],
#  'Obesity': ['increased fat'],
#  'Osteoarthritis': ['joint pain',
#   'stiffness',
#   'joint swelling',
#   'decreased range motion'],
#  'Psoriasis': ['red purple darker skin', 'itchy', 'scaly patch skin'],
#  "Parkinson's Disease": ['tremor',
#   'rigidity',
#   'slowness movement',
#   'difficulty walking'],
#  'Pericarditis': ['sharp chest pain', 'better sitting worse lying', 'fever'],
#  'Pneumonia': ['cough', 'difficulty breathing', 'rapid breathing', 'fever'],
#  'Poliomyelitis': ['muscle weakness resulting inability move'],
#  'Pterygium': ['pinkish', 'triangular tissue growth cornea'],
#  'Polycystic ovary syndrome (PCOS)': ['irregular menstrual period',
#   'heavy period',
#   'excess hair',
#   'acne',
#   'pelvic pain',
#   'difficulty getting pregnant',
#   'patch thick',
#   'darker',
#   'velvety skin'],
#  'Plague': ['fever', 'weakness', 'headache'],
#  'Preterm birth': ['birth baby younger week gestational age'],
#  'Preeclampsia': ['high blood pressure', 'protein urine'],
#  'Pellucid Marginal Degeneration': ['vision loss'],
#  'Presbyopia': ['difficulty reading small print',
#   'hold reading material farther away',
#   'headache',
#   'eyestrain'],
#  'Premenstrual syndrome': ['acne',
#   'tender breast',
#   'cramp',
#   'bloating',
#   'feeling tired',
#   'sore throat',
#   'mood change'],
#  'Puerperal sepsis': ['fever',
#   'lower abdominal pain',
#   'bad smelling vaginal discharge'],
#  'Postpartum haemorrhage': ['significant blood loss childbirth',
#   'increased heart rate',
#   'feeling faint upon standing',
#   'increased breath rate'],
#  'Post-herpetic neuralgia': ['burning stabbing pain',
#   'pain doesnt end shingle subsides'],
#  'Postpartum depression/ Perinatal depression': ['extreme sadness',
#   'low energy',
#   'anxiety',
#   'change sleeping eating pattern',
#   'cry episode',
#   'irritability'],
#  'Quinsy': ['fever', 'throat pain', 'trouble opening mouth', 'change voice'],
#  'Rabies': ['fever',
#   'fear water',
#   'confusion',
#   'excessive salivation',
#   'hallucination',
#   'trouble sleeping',
#   'paralysis',
#   'coma'],
#  "Raynaud's Phenomenon": ['affected part turning white',
#   'blue',
#   'red',
#   'burning'],
#  'Rubella': ['rash',
#   'swollen lymph node',
#   'fever',
#   'sore throat',
#   'feeling tired'],
#  'Rheumatic fever and rheumatic heart disease': ['fever',
#   'multiple painful joint',
#   'involuntary muscle movement',
#   'erythema marginatum'],
#  'Sarcoidosis': ['depends organ involved'],
#  'Sarcoma': ['swell pain near tumor'],
#  'Schizophrenia': ['hallucination usually hearing voice',
#   'delusion',
#   'paranoia',
#   'confused thinking'],
#  'Scurvy': ['weakness',
#   'feeling tired',
#   'change hair',
#   'sore arm leg',
#   'gum disease',
#   'easy bleeding'],
#  'Severe Acute Respiratory Syndrome (SARS)': ['fever',
#   'persistent dry cough',
#   'headache',
#   'muscle pain',
#   'difficulty breathing'],
#  'Syphilis': ['firm', 'painless', 'non itchy skin ulcer'],
#  'Superior Limbic Keratoconjunctivitis': ['eye redness',
#   'burning sensation',
#   'tearing'],
#  'Stroke': ['inability move feel one side body',
#   'problem understanding speaking',
#   'dizziness',
#   'loss vision one side'],
#  'Scrub Typhus': ['fever', 'headache', 'rash'],
#  'Sexually transmitted infections (STIs)': ['vaginal discharge',
#   'penile discharge',
#   'ulcer around genitals',
#   'pelvic pain'],
#  'Shaken Baby Syndrome': ['variable'],
#  'Substance abuse': ['relationship difficulty',
#   'legal problem',
#   'problem work school',
#   'insomnia',
#   'irritability',
#   'chronic fatigue'],
#  'Scabies': ['itchiness', 'pimple like rash'],
#  'Sub-conjunctival Haemorrhage': ['red spot white eye', 'little pain'],
#  'Tetanus': ['muscle spasm', 'fever', 'headache'],
#  'Thalassaemia': ['feeling tired',
#   'pale skin',
#   'enlarged spleen',
#   'yellowish skin',
#   'dark urine'],
#  'Tuberculosis': ['chronic cough',
#   'fever',
#   'cough bloody mucus',
#   'weight loss'],
#  'Turners Syndrome': ['webbed neck', 'short stature', 'swollen hand foot'],
#  'Trachoma': ['eye pain', 'blindness'],
#  'Taeniasis/cysticercosis': ['cm lump skin'],
#  'Typhoid / Enteric Fever': ['fever start low increase daily',
#   'possibly reaching high f c headache',
#   'weakness fatigue',
#   'muscle ache',
#   'sweating',
#   'dry cough',
#   'loss appetite weight loss',
#   'stomach pain',
#   'diarrhea constipation',
#   'rash',
#   'swollen stomach enlarged liver spleen'],
#  'Ulcerative Colitis': ['abdominal pain',
#   'diarrhea mixed blood',
#   'weight loss',
#   'fever',
#   'anemia'],
#  'Urticaria': ['red', 'raised', 'itchy bump'],
#  'Varicose Veins': ['fullness', 'pain area'],
#  'Vitamin B12 Deficiency': ['presence anemia',
#   'decreased ability think',
#   'depression',
#   'irritability',
#   'abnormal sensation',
#   'change reflex'],
#  'Vitiligo': ['patch white skin'],
#  'Xerophthalmia': ['night blindness'],
#  'Yellow Fever': ['fever', 'chill', 'muscle pain', 'headache', 'yellow skin'],
#  'Yaws': ['hard swelling skin', 'ulcer', 'joint bone pain']}

# %%
total_symptoms = list(total_symp)
total_symptoms.sort()
total_symptoms=['disease_name']+total_symptoms

# %%
total_symptoms
# Out:
# ['disease_name',
#  'abdominal pain',
#  'abnormal bleeding',
#  'abnormal sensation',
#  'abnormally frequent',
#  'abnormally small head brain',
#  'abscess',
#  'acne',
#  'acquiring drinking alcohol taking lot time',
#  'affected part turning white',
#  'anemia',
#  'anxiety',
#  'arm',
#  'asthenopia',
#  'asymptomatic',
#  'back',
#  'bad breath',
#  'bad smelling vaginal discharge',
#  'barking cough',
#  'better sitting worse lying',
#  'birth baby younger week gestational age',
#  'black area skin',
#  'bleeding',
#  'bleeding gum',
#  'bleeding skin',
#  'blindness',
#  'blister break open form small ulcer',
#  'bloating',
#  'blood stool',
#  'bloody diarrhea',
#  'blue',
#  'blurred vision',
#  'blurry vision',
#  'breast',
#  'breathing problem',
#  'bruising',
#  'burning',
#  'burning sensation',
#  'burning stabbing pain',
#  'burning urination',
#  'case asymptomatic',
#  'certain thought repeatedly',
#  'change bowel movement',
#  'change breast shape',
#  'change hair',
#  'change reflex',
#  'change skin color red black',
#  'change sleeping eating pattern',
#  'change taste',
#  'change time',
#  'change voice',
#  'characteristic facial feature',
#  'chest discomfort',
#  'chest pain',
#  'chest tightness',
#  'chill',
#  'chronic cough',
#  'chronic fatigue',
#  'close object appear normal',
#  'clumsiness',
#  'cm lump skin',
#  'cold sweat',
#  'coma',
#  'confused thinking',
#  'confusion',
#  'constipation',
#  'coolness',
#  'corneal ulceration',
#  'cough',
#  'cough bloody mucus',
#  'coughing',
#  'coughing mucus',
#  'cramp',
#  'crusty eyelid',
#  'cry episode',
#  'dark urine',
#  'darker',
#  'daytime sleepiness',
#  'decreased ability feel pain',
#  'decreased ability hear',
#  'decreased ability see',
#  'decreased ability think',
#  'decreased ability think remember',
#  'decreased appetite',
#  'decreased motivation',
#  'decreased range motion',
#  'decreased taste',
#  'decreased vision',
#  'dehydration',
#  'delayed physical growth',
#  'delusion',
#  'depends location runny nose',
#  'depends organ involved',
#  'depressed mood',
#  'depression',
#  'developmental disability',
#  'diarrhea',
#  'diarrhea constipation',
#  'diarrhea mixed blood',
#  'diarrhoea',
#  'diarrhoea may bloody',
#  'difficulty breathing',
#  'difficulty cutting',
#  'difficulty eating',
#  'difficulty getting pregnant',
#  'difficulty reading small print',
#  'difficulty remembering recent event',
#  'difficulty socializing others',
#  'difficulty swallowing',
#  'difficulty walking',
#  'dimpling skin',
#  'discharge',
#  'discharge penis',
#  'disorientation',
#  'distance near blur',
#  'distant object appear blurry',
#  'distorted blurred vision distance',
#  'dizziness',
#  'drinking large amount alcohol long period',
#  'dry cough',
#  'dry damp skin',
#  'dry eye',
#  'dry mouth',
#  'dryness',
#  'ear pain',
#  'easy bleeding',
#  'easy prolonged bleeding',
#  'emotional problem',
#  'enlarged liver',
#  'enlarged spleen',
#  'enlarged thyroid',
#  'erythema',
#  'erythema marginatum',
#  'excess hair',
#  'excessive amount uterine bleeding',
#  'excessive daytime sleepiness',
#  'excessive salivation',
#  'extreme sadness',
#  'eye discharge',
#  'eye pain',
#  'eye pain photophobia',
#  'eye redness',
#  'eye strain',
#  'eyestrain',
#  'facial swelling',
#  'fast heartbeat',
#  'fatigue',
#  'fear water',
#  'feel need check thing repeatedly',
#  'feeling cold',
#  'feeling faint',
#  'feeling faint upon standing',
#  'feeling inferiority',
#  'feeling like passing',
#  'feeling tired',
#  'fever',
#  'fever start low increase daily',
#  'firm',
#  'firmly attached white patch mucous membrane',
#  'flat discolored spot bump may blister',
#  'flatulence',
#  'flu like illness',
#  'fluid nipple',
#  'frequent urination',
#  'fullness',
#  'genitals',
#  'gum disease',
#  'half ring finger',
#  'hallucination',
#  'hallucination usually hearing voice',
#  'hard swelling skin',
#  'headache',
#  'hearing loss',
#  'heartburn',
#  'heavy period',
#  'high blood pressure',
#  'high body temperature',
#  'hoarse voice',
#  'hold reading material farther away',
#  'hunger',
#  'hypervigilance',
#  'inability child',
#  'inability move facial muscle one side',
#  'inability move feel one side body',
#  'increased breath rate',
#  'increased fat',
#  'increased heart rate',
#  'increased hunger',
#  'increased risk broken bone',
#  'increased risk infection',
#  'increased thirst',
#  'index',
#  'infertility',
#  'inflamed eye',
#  'insomnia',
#  'intellectual disability',
#  'involuntary muscle movement',
#  'involuntary sleep episode',
#  'irregular',
#  'irregular menstrual period',
#  'irritability',
#  'irritation',
#  'itchiness',
#  'itchy',
#  'itchy blister',
#  'itchy bump',
#  'jaw',
#  'joint bone pain',
#  'joint pain',
#  'joint swelling',
#  'large amount watery diarrhea',
#  'leg',
#  'legal problem',
#  'light sensitivity',
#  'limited range motion ankle',
#  'little pain',
#  'liver dysfunction',
#  'localized breast pain redness',
#  'loose frequent bowel movement',
#  'loose teeth',
#  'loss appetite',
#  'loss appetite weight loss',
#  'loss hair part head body',
#  'loss smell',
#  'loss taste smell',
#  'loss vision one side',
#  'low energy',
#  'low red blood cell',
#  'low self esteem',
#  'lower abdominal pain',
#  'lump',
#  'lump breast',
#  'lump bump neck',
#  'malaise',
#  'may symptom',
#  'memory problem',
#  'mental change',
#  'mid dilated pupil',
#  'middle finger',
#  'mild moderate intellectual disability',
#  'minimal',
#  'missed period',
#  'mood change',
#  'mood swing',
#  'multiple painful joint',
#  'muscle ache',
#  'muscle cramp',
#  'muscle joint pain',
#  'muscle pain',
#  'muscle spasm',
#  'muscle weakness',
#  'muscle weakness beginning foot hand',
#  'muscle weakness resulting inability move',
#  'muscular pain',
#  'nausea',
#  'nausea vomiting',
#  'nausea vomiting weight loss dehydration occur',
#  'near blur',
#  'nearly undetectable spell',
#  'nearsightedness',
#  'neck',
#  'neck stiffness',
#  'neurological impairment',
#  'newly inverted nipple',
#  'night blindness',
#  'non itchy skin ulcer',
#  'non painful cyst middle eyelid',
#  'nonaligned eye',
#  'numbness',
#  'object different size eye',
#  'one eye myopia eye hyperopia',
#  'opening upper lip may extend nose palate',
#  'overlying redness',
#  'pain',
#  'pain area',
#  'pain around ear',
#  'pain doesnt end shingle subsides',
#  'pain specific bone',
#  'painful',
#  'painful blister white worm crawl',
#  'painful heavy period',
#  'painless',
#  'painless lump',
#  'pale color',
#  'pale skin',
#  'pallor',
#  'paralysis',
#  'paranoia',
#  'parotitis non specific symptom fever',
#  'patch thick',
#  'patch white skin',
#  'pelvic pain',
#  'penile discharge',
#  'perform certain routine repeatedly',
#  'period vigorous shaking',
#  'persistent dry cough',
#  'persistent rough white red patch mouth lasting longer week',
#  'photophobia',
#  'physical disability',
#  'pimple like rash',
#  'pinkish',
#  'playing video game extremely long period time',
#  'poor appetite',
#  'poor tolerance heat',
#  'possibly reaching high f c headache',
#  'post nasal drip',
#  'presence anemia',
#  'presence restricted interest repetitive behavior',
#  'problem gambling',
#  'problem language',
#  'problem understanding speaking',
#  'problem vision',
#  'problem work school',
#  'prolonged',
#  'prolonged cough',
#  'protein urine',
#  'purple colored skin lesion',
#  'raised',
#  'raised red blue lesion',
#  'rapid breathing',
#  'rash',
#  'recurring episode wheezing',
#  'red',
#  'red eye',
#  'red purple darker skin',
#  'red scaly patch skin breast',
#  'red skin',
#  'red spot white eye',
#  'red without blister',
#  'reddish eye',
#  'redness',
#  'redness eye',
#  'redness sweating cheek area salivating',
#  'relationship difficulty',
#  'right lower abdominal pain',
#  'rigidity',
#  'runny nose',
#  'scaly patch skin',
#  'scratchiness',
#  'seizure',
#  'sensitivity light',
#  'sensitivity smell',
#  'sensitivity sound',
#  'severe swelling arm',
#  'sharp chest pain',
#  'short stature',
#  'shortness breath',
#  'significant blood loss childbirth',
#  'skin breakdown',
#  'skin ulcer',
#  'sleep problem',
#  'sleeping problem',
#  'slowness movement',
#  'small',
#  'small blister surrounding swelling',
#  'snoring',
#  'social isolation',
#  'social withdrawal',
#  'sore arm leg',
#  'sore throat',
#  'stiff neck',
#  'stiffness',
#  'stomach pain',
#  'sudden loss muscle strength',
#  'sweating',
#  'swell pain near tumor',
#  'swelling',
#  'swollen',
#  'swollen hand foot',
#  'swollen lymph node',
#  'swollen stomach enlarged liver spleen',
#  'taste acid',
#  'tearing',
#  'temporary fleeting vision one eye',
#  'tender breast',
#  'tenderness',
#  'testicular pain',
#  'throat pain',
#  'tingling hand foot',
#  'tingling thumb',
#  'tiredness',
#  'tooth loss',
#  'tremor',
#  'triangular tissue growth cornea',
#  'trouble breathing nose',
#  'trouble opening mouth',
#  'trouble sleeping',
#  'trouble social interaction',
#  'ulcer',
#  'ulcer around genitals',
#  'ulceration',
#  'unexplained weight loss',
#  'unpleasant smell present breath',
#  'usage resulting problem',
#  'usually ascending',
#  'vaginal bleeding',
#  'vaginal bleeding without pain',
#  'vaginal discharge',
#  'variable',
#  'vary depending part brain involved',
#  'velvety skin',
#  'verbal nonverbal communication',
#  'vision loss',
#  'vomiting',
#  'vomiting blood',
#  'weak grip',
#  'weakness',
#  'weakness fatigue',
#  'webbed neck',
#  'weight loss',
#  'wheezing',
#  'widespread pain',
#  'withdrawal occurring stopping',
#  'yellow skin',
#  'yellowish coloration skin white eye',
#  'yellowish skin']

# %%
df = pd.DataFrame(columns = total_symptoms)

# %%
from itertools import combinations
from tqdm import tqdm

# %%
for key,value in tqdm(cleaned_symp_dict.items()):
    key = str.encode(key).decode('utf-8')
    for comb in range(1,len(value)+1):
        for subset in combinations(value,comb):
            row_comb = dict({x:0 for x in total_symptoms})
            for sym in list(subset):
                row_comb[sym]=1
            row_comb['disease_name']=key
            df = df.append(pd.Series(row_comb),ignore_index=True)
# Out:
# 100%|██████████| 178/178 [21:00<00:00,  7.08s/it]

# %%
df.shape
# Out:
# (14343, 416)

# %%
df.to_csv("disease_symptoms_dataset_comb.csv",index=None)
